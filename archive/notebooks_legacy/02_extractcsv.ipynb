# %%
# %pip install pandas -q
import pandas as pd
import os
from pathlib import Path


data_dir = Path("../data") 
csv_files = list(data_dir.rglob("*.csv"))

print(f"Found {len(csv_files)} CSV files")

csv_files = list(Path(data_dir).rglob('*.csv'))

print(f"Found {len(csv_files)} CSV files:\n")

for csv_file in csv_files:
    print(f"File: {csv_file.relative_to(data_dir)}")
    print("-" * 80)
    
    df = pd.read_csv(csv_file)
    print(f"Shape: {df.shape} (rows, columns)")
    print(f"Columns: {list(df.columns)}")
    print("\nFirst few rows:")
    print(df.head(10))
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Found 79 CSV files
# Found 79 CSV files:
#
# File: Y29uaXRlLmdib2RvZ2JlQHVtNnAubWE=_1771261975584/output_data_points.csv
# --------------------------------------------------------------------------------
# Shape: (691, 14) (rows, columns)
# Columns: ['id', 'lat', 'lon', 'property', 'original_name', 'upper_depth_cm', 'lower_depth_cm', 'value', 'unit', 'sampling_date', 'license', 'h3_index', 'publication_date', 'data_source']
#
# First few rows:
#    id        lat        lon  property  original_name  upper_depth_cm  \
# 0   1  46.682264  15.997542  nematode  Nematode_herb               0
# 1   2  46.682264  15.997542  nematode  Nematode_bact               0
# 2   3  46.682264  15.997542  nematode  Nematode_pred               0
# 3   4  46.682264  15.997542  nematode  Nematode_unid               0
# ...

# %%
dfs = []
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)

print(f"Combined dataframe shape: {combined_df.shape} (rows, columns)")

print(f"\nFirst few rows of combined data:")
combined_df.head(10)
# Out:
# Combined dataframe shape: (1278483, 14) (rows, columns)
#
# First few rows of combined data:
#    id        lat        lon  property  original_name  upper_depth_cm  \
# 0   1  46.682264  15.997542  nematode  Nematode_herb             0.0
# 1   2  46.682264  15.997542  nematode  Nematode_bact             0.0
# 2   3  46.682264  15.997542  nematode  Nematode_pred             0.0
# 3   4  46.682264  15.997542  nematode  Nematode_unid             0.0
# 4   5  46.682264  15.997542  nematode   Nematode_tot             0.0
# 5   6  46.682264  15.997542  nematode  Nematode_omni             0.0
# 6   7  46.682264  15.997542  nematode  Nematode_fung             0.0
# 7   8  46.277222  14.571111  nematode  Nematode_herb             3.0
# 8   9  46.277222  14.571111  nematode  Nematode_bact             3.0
# 9  10  46.277222  14.571111  nematode  Nematode_pred             3.0
#
#    lower_depth_cm        value                 unit  sampling_date    license  \
# ...

# %%
output_path = '/home/agbelgaid/Documents/WORKSPACE/DataCollection/SoilHive/data/combined_output_data_points.csv'
combined_df.to_csv(output_path, index=False)
print(f"\nCombined CSV saved to: {output_path}")
print(f"Total rows: {len(combined_df)}")
print(f"Total columns: {len(combined_df.columns)}")
# Out:
# Combined CSV saved to: /home/agbelgaid/Documents/WORKSPACE/DataCollection/SoilHive/data/combined_output_data_points.csv
# Total rows: 1278483
# Total columns: 14

# %%
combined_df['data_source'].unique(), combined_df['property'].unique(), combined_df['sampling_date'].unique()
# Out:
# (array(['Global Soil Nematode DB', 'WoSIS', 'CAROB'], dtype=object),
#  array(['nematode', 'sand', 'occ', 'clay', 'TC', 'pH', 'silt', 'CEC', 'BD',
#         'CF', 'CaCO3', 'N', 'EC', 'P', 'WR_volumetric', 'WR_gravimetric',
#         'Na', 'Mg', 'K', 'Ca'], dtype=object),
#  array([  nan, 1981., 1992., 1980., 1973., 1985., 1994., 2005., 1978.,
#         2004., 1976., 1970., 1979., 1987., 1986., 1974., 1982., 1990.,
#         1991., 1964., 1967., 1963., 1962., 1966., 1972., 1989., 1958.,
#         1965., 1977., 1971., 1969., 1968., 1975., 1961., 1983., 1996.,
#         1984., 1960., 2001., 2000., 2003., 2006., 2007., 2008., 2002.,
#         1998., 1993., 2009., 1959., 2013., 1918., 1995., 1997., 1999.,
#         1988., 1928., 2010., 2011., 2014., 2012., 1953., 1957., 1956.,
#         1955., 1951., 1952., 2015., 1946., 1950., 2016., 2018., 2017.]))
